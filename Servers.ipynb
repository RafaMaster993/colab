# %% [markdown]
# **¡Ejecuta un servidor de Minecraft en Google Colab!**
#
# ---

# %% [markdown]
# # Iniciar el servidor simepre aqui
#
# El siguiente script iniciará tu servidor. Debes crear primero un servidor para poder utilizarlo siguiendo los pasos del video de mi canal Youtube @hdn1947 .

# %%
import os
import re
import json
from google.colab import drive

# Verificar la versión de Java
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "11" :
  # Actualizar la lista de paquetes
  # !sudo apt update &>/dev/null && echo "apt actualizado correctamente" || echo "error al actualizar apt"

  # Eliminar Java 11 hdn1947
  # !sudo apt remove -y openjdk-11-jdk-headless openjdk-11-jre-headless &>/dev/null && echo "Java 11 eliminado correctamente" || echo "error al eliminar Java 11"
  # !sudo apt autoremove -y &>/dev/null && echo "paquetes limpiados correctamente" || echo "error al limpiar paquetes"
  
  # Instalar Java 21
  # !sudo apt install -y wget apt-transport-https &>/dev/null && echo "wget y apt-transport-https instalados" || echo "error al instalar wget y apt-transport-https"
  # !mkdir -p /etc/apt/keyrings &>/dev/null && echo "directorio de claves creado" || echo "error al crear directorio de claves"
  # !wget -O - https://packages.adoptium.net/artifactory/api/gpg/key/public | tee /etc/apt/keyrings/adoptium.asc &>/dev/null && echo "obteniendo claves" || echo "error al obtener claves"
  # !echo "deb [signed-by=/etc/apt/keyrings/adoptium.asc] https://packages.adoptium.net/artifactory/deb $(awk -F= '/^VERSION_CODENAME/{print$2}' /etc/os-release) main" | tee /etc/apt/sources.list.d/adoptium.list &>/dev/null && echo "claves agregadas" || echo "error al agregar claves"
  # !sudo apt update &>/dev/null && echo "apt actualizado correctamente" || echo "error al actualizar apt"
  # !sudo apt install temurin-21-jdk &>/dev/null && echo "Java 21 instalado correctamente." || echo "error al instalar Java 21."
  
  # Limpiar la lista de paquetes hdn1947
  # !sudo apt clean &>/dev/null && echo "paquetes limpiados correctamente" || echo "error al limpiar paquetes"
  
  # Verificar la versión de Java nuevamente hdn1947
  java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "21" :
  print("Java 21 está funcionando correctamente, puedes continuar hdn1947.")

  # Montar Google Drive
  drive.mount('/content/drive')
  
  # Cambiar de directorio
  # %cd "/content/drive/My Drive/minecraft-server"

  # !ls # listar contenido del directorio

  # Importar archivo de configuración.
  if os.path.isfile("colabconfig.json"):
    colabconfig = json.load(open("colabconfig.json"))
  else:
    colabconfig = {"server_type": "generic"} # usando el valor predeterminado si no existe la configuración.
    json.dump(colabconfig, open("colabconfig.json",'w'))

  # Nombres de los archivos jar del servidor.
  jar_list = {'paper': 'server.jar', 'purpur': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar'}
  jar_name = jar_list[colabconfig["server_type"]]

  # Argumentos de Java.
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
  memory_allocation = "-Xms8704M -Xmx8704M"

  # Elegir servicio de túnel
  # Opcione disponible: playit
  tunnel_service = "playit"
  print("Usando", tunnel_service)
  
  if tunnel_service == "playit":
    # !curl -SsL https://playit-cloud.github.io/ppa/key.gpg | gpg --dearmor | sudo tee /etc/apt/trusted.gpg.d/playit.gpg >/dev/null
    # !echo "deb [signed-by=/etc/apt/trusted.gpg.d/playit.gpg] https://playit-cloud.github.io/ppa/data ./" | sudo tee /etc/apt/sources.list.d/playit-cloud.list
    # !sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg instalado" || echo "error al instalar Playit.gg"
    print('Iniciando servidor...')
    # !playit & java $memory_allocation $server_flags -jar $jar_name nogui
  
  else:
    print('Servicio de túnel no válido')
else:
  print("Java 21 no está instalado o no está funcionando")

# %% [markdown]
# # Crear un servidor
#
# El siguiente script descargará un servidor y aceptará el EULA. Luego podrás iniciarlo.como lo ves en el video del canal de Youtube @hdn1947

# %%
from google.colab import drive
import requests
import json

# Reemplazar "1.21" con la versión que desees.
# Versiones disponibles:
# - 1.21.4
# - 1.21.2
# - 1.21.1
# - 1.21
# - 1.20.6
# - 1.20.5
# - 1.20.4
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8
# Puede que las viejas versiones funcionen, pero no se garantiza.
version = '1.20'

# Elegir tipo de servidor. Versiones disponibles: paper, purpur, fabric
server_type = 'paper'

drive.mount('/content/drive')
# !mkdir "/content/drive/My Drive/minecraft-server"
# %cd "/content/drive/My Drive/minecraft-server"

if server_type == "paper":
  a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
  b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
  url = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]
  jar_name = "server.jar"

elif server_type == "purpur":
  url = f"https://api.purpurmc.org/v2/purpur/{version}/latest/download"
  jar_name = "server.jar"

elif server_type == "fabric":
  url = "https://maven.fabricmc.net/net/fabricmc/fabric-installer/1.0.1/fabric-installer-1.0.1.jar"
  jar_name = "fabric-installer.jar"

print('Descargando a Google Drive...')
r = requests.get(url)
if r.status_code == 200:
  with open('/content/drive/My Drive/minecraft-server/' + jar_name, 'wb') as f:
    f.write(r.content)
else:
  print('¡Error '+ str(r.status_code) + '! Parece que elegiste una versión no compatible. Intenta ejecutar el script nuevamente.')

if server_type == "fabric":
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

colabconfig = {"server_type": server_type}
json.dump(colabconfig, open("colabconfig.json",'w'))

# Aceptar el EULA
# %cd "/content/drive/My Drive/minecraft-server"
# !echo "eula=true" >> eula.txt

print('¡Listo!')
